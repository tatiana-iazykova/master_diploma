# %%
import pandas as pd
import ast
from tqdm import tqdm
pd.set_option('display.max_rows', None)
tqdm.pandas()

# %%
df = pd.read_excel('parsed_df.xlsx', engine='openpyxl')

# %%
df.head()
# Out:
#          pmcs                                patient_description  \
# 0  PMC7200342  Case 1 is a 45-year-old woman, with no obvious...
# 1  PMC7200342  Case 2 is a 67-year-old woman who suffered fro...
# 2  PMC7200342  Case 3 is a 72-year-old male with a history of...
# 3  PMC7200342  Case 4 is a 77-year-old male admitting to emer...
# 4  PMC7303641  A 55-year old male was referred to the hospita...
#
#   Clinical characteristics C-reactive protein, mg/dL D-Dimer  Age  \
# 0                      NaN                       142     803  NaN
# 1                      NaN                         4    1040  NaN
# 2                      NaN                        33     644  NaN
# 3                      NaN                       366     378  NaN
# 4                      NaN                        12      82   56
#
#   Prothrombin time   Sex Creatinine mg/dl White blood cell count  ...  \
# 0              NaN   NaN              NaN                    NaN  ...
# 1              NaN   NaN              NaN                    NaN  ...
# 2              NaN   NaN              NaN                    NaN  ...
# 3              NaN   NaN              NaN                    NaN  ...
# 4              NaN  Male              NaN                    NaN  ...
#
#   Hematocrit (%) ICU admission Race Hospital LOS (d) Highest temperature, °C  \
# 0            NaN           NaN  NaN              NaN                     NaN
# 1            NaN           NaN  NaN              NaN                     NaN
# 2            NaN           NaN  NaN              NaN                     NaN
# 3            NaN           NaN  NaN              NaN                     NaN
# 4            NaN           NaN  NaN              NaN                     NaN
#
#   Monocytes GFR (ml/min) Duration of symptoms Potassium (mEq/L) Risc factors
# 0       NaN          NaN                  NaN               NaN          NaN
# 1       NaN          NaN                  NaN               NaN          NaN
# 2       NaN          NaN                  NaN               NaN          NaN
# 3       NaN          NaN                  NaN               NaN          NaN
# 4       NaN          NaN                 ≈ 14               NaN          NaN
#
# [5 rows x 52 columns]

# %%
df_ner = pd.read_excel('thesis_dataframe.xlsx', engine='openpyxl')

# %%
df_ner[df_ner.pmcs == 'PMC7200342']
# Out:
#           pmcs                                patient_description  \
# 65  PMC7200342  Case 4 is a 77-year-old male admitting to emer...
# 66  PMC7200342  Case 3 is a 72-year-old male with a history of...
# 67  PMC7200342  Case 2 is a 67-year-old woman who suffered fro...
# 68  PMC7200342  Case 1 is a 45-year-old woman, with no obvious...
#
#                                                markup
# 65  [(12, 14, 'Age'), (24, 28, 'Sex'), (62, 67, 'H...
# 66  [(12, 14, 'Age'), (24, 28, 'Sex'), (47, 59, 'C...
# 67  [(12, 14, 'Age'), (24, 29, 'Sex'), (48, 58, 'C...
# 68  [(12, 14, 'Age'), (24, 29, 'Sex'), (113, 132, ...

# %%
df_with_markup = df.merge(df_ner[['pmcs', 'patient_description', 'markup']], on=['pmcs', 'patient_description'])

# %%
def get_relevant_entity(text, labels):
    res = {}
    labels = ast.literal_eval(labels)
    if labels:
        for ent in labels:        
            entity = text[ent[0]:ent[1]]
            entity = entity.strip()

            if ent[2] not in res:
                res[ent[2]] = [entity]
            else:
                res[ent[2]].append(entity)
    return res

# %%
df_with_markup['ners_true'] = df_with_markup.progress_apply(lambda x: get_relevant_entity(
    text=x['patient_description'], 
    labels=x['markup']
), axis=1)
# Out:
# 100%|██████████| 247/247 [00:00<00:00, 4938.36it/s]

# %%
col_list = list(df.columns)

col_list.remove('pmcs')
col_list.remove('patient_description')

# %%
df_with_markup.fillna(value='NaN', inplace=True)

# %%
for i, row in df_with_markup.iterrows():
    for col in col_list:
        if row[col] == 'NaN' and col in row['ners_true']:
            df_with_markup.at[i, col] = '; '.join(row['ners_true'][col])

# %%
def fill_death(x):
    if x == 'NaN':
        return 0
    x = x.lower()
    
    markers = ['died', 'expired', 'passed', 'terminal', 'death', 'yes', 'diseaced']
    for m in markers:
        if m in x:
            return 1
    return 0

# %%
df_with_markup['Death'] = df_with_markup['Death'].apply(fill_death)

# %%
df_with_markup.head()
# Out:
#          pmcs                                patient_description  \
# 0  PMC7200342  Case 1 is a 45-year-old woman, with no obvious...
# 1  PMC7200342  Case 2 is a 67-year-old woman who suffered fro...
# 2  PMC7200342  Case 3 is a 72-year-old male with a history of...
# 3  PMC7200342  Case 4 is a 77-year-old male admitting to emer...
# 4  PMC7303641  A 55-year old male was referred to the hospita...
#
#                             Clinical characteristics  \
# 0  left facial paresis; dysarthria; left hemipare...
# 1  dysarthria; right hemiparesis; upper respirato...
# 2  hypertension; loss of consciousness; dysarthri...
# 3  cough; shortness of breath; left hemi-hypoesth...
# 4  suspected deep vein thrombosis (DVT); unilater...
#
#   C-reactive protein, mg/dL D-Dimer Age Prothrombin time    Sex  \
# 0                       142     803  45              NaN  woman
# 1                         4    1040  67              NaN  woman
# 2                        33     644  72              NaN   male
# 3                       366     378  77              NaN   male
# 4                        12      82  56              NaN   Male
#
#   Creatinine mg/dl White blood cell count  ...  Race Hospital LOS (d)  \
# 0              NaN                    NaN  ...   NaN              NaN
# 1              NaN                    NaN  ...   NaN              NaN
# 2              NaN                    NaN  ...   NaN              NaN
# 3              NaN                    NaN  ...   NaN              NaN
# 4              NaN                    NaN  ...   NaN              NaN
#
#   Highest temperature, °C Monocytes GFR (ml/min) Duration of symptoms  \
# 0              high fever       NaN          NaN                  NaN
# 1      intermittent fever       NaN          NaN                  NaN
# 2                     NaN       NaN          NaN                  NaN
# 3                   fever       NaN          NaN                  NaN
# 4                     NaN       NaN          NaN                 ≈ 14
#
#   Potassium (mEq/L) Risc factors  \
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
#
#                                               markup  \
# 0  [(12, 14, 'Age'), (24, 29, 'Sex'), (113, 132, ...
# 1  [(12, 14, 'Age'), (24, 29, 'Sex'), (48, 58, 'C...
# 2  [(12, 14, 'Age'), (24, 28, 'Sex'), (47, 59, 'C...
# 3  [(12, 14, 'Age'), (24, 28, 'Sex'), (62, 67, 'H...
# 4  [(2, 4, 'Sex'), (14, 18, 'Age'), (53, 89, 'Cli...
#
#                                            ners_true
# 0  {'Age': ['45'], 'Sex': ['woman'], 'Clinical ch...
# 1  {'Age': ['67'], 'Sex': ['woman'], 'Clinical ch...
# 2  {'Age': ['72'], 'Sex': ['male'], 'Clinical cha...
# 3  {'Age': ['77'], 'Sex': ['male'], 'Highest temp...
# 4  {'Sex': ['55'], 'Age': ['male'], 'Clinical cha...
#
# [5 rows x 54 columns]

# %%
# df_with_markup.to_csv('df_with_markup.csv', index=False)

# %%
df_for_modelling = df_with_markup.loc[:, ~df_with_markup.columns.isin(['pmcs', 'markup', 'ners_true'])]

# %%
X = df_for_modelling.loc[:, df_for_modelling.columns != 'Death']
y = df_for_modelling['Death']

# %%
col_list_X = list(X.columns)
col_list_X.remove('patient_description')

# %%
def collect_vectors(row, col_list=col_list_X):
    text = []
    for col in col_list:
        if row[col] != 'NaN':
            text.append(str(row[col]))
    return ' '.join(text)

# %%
X['vectors'] = X.progress_apply(
    lambda row: collect_vectors(row=row, col_list=col_list_X),
    axis=1
)
# Out:
# 100%|██████████| 247/247 [00:00<00:00, 5735.60it/s]

# %% [markdown]
# # Tf-idf + Logreg

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
import eli5

# %%
import spacy

nlp = spacy.load('ru_core_news_md')

# %%
def get_clean_sents(text):
    doc = nlp(text)
    new_text = []
    markers = ['died', 'expired', 'passed', 'terminal', 'death', 'diseaced', 'discharged']
    for sent in doc.sents:
        sent = sent.text
        
        flag = True
        for m in markers:
            if m in sent:
                flag = False
                break
        if flag:
            new_text.append(sent)
    return ' '.join(new_text)

# %%
X['patient_description_wo_death'] = X['patient_description'].progress_apply(get_clean_sents)
# Out:
# 100%|██████████| 247/247 [00:06<00:00, 39.86it/s]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_patient_train = X_train['patient_description']
X_patient_test = X_test['patient_description']

# %%
X_patient_train_honest = X_train['patient_description_wo_death']
X_patient_test_honest = X_test['patient_description_wo_death']

# %%
X_rest_train = X_train['vectors']
X_rest_test = X_test['vectors']

# %%
X_all_train = X_train['patient_description_wo_death'] + ' ' + X_train['vectors']
X_all_test = X_test['patient_description_wo_death'] + ' ' + X_test['vectors']

# %%
steps = [
    ('vectorizer', TfidfVectorizer(min_df=0.1, max_df=0.5)),
    ('logreg', LogisticRegression(C=25))
]

pipe = Pipeline(steps=steps)

# %%
pipe.fit(X_patient_train, y_train)

preds = pipe.predict(X_patient_test)

print(classification_report(y_true=y_test, y_pred=preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93        60
#            1       0.77      0.67      0.71        15
#
#     accuracy                           0.89        75
#    macro avg       0.84      0.81      0.82        75
# weighted avg       0.89      0.89      0.89        75

# %%
report = classification_report(y_test, preds, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report = df_classification_report.round(decimals=2)

df_classification_report = df_classification_report.astype(str)
df_classification_report.at['accuracy', 'precision'] = ''
df_classification_report.at['accuracy', 'recall'] = ''
df_classification_report.at['accuracy', 'support'] = df_classification_report.at['macro avg', 'support']
df_classification_report['support'] = df_classification_report['support'].str.replace('[.]0', '')

# %%
print(df_classification_report.to_latex())
# Out:
# \begin{tabular}{lllll}
# \toprule
# {} & precision & recall & f1-score & support \\
# \midrule
# 0            &      0.92 &   0.95 &     0.93 &      60 \\
# 1            &      0.77 &   0.67 &     0.71 &      15 \\
# accuracy     &           &        &     0.89 &      75 \\
# macro avg    &      0.84 &   0.81 &     0.82 &      75 \\
# weighted avg &      0.89 &   0.89 &     0.89 &      75 \\
# \bottomrule
# \end{tabular}

# %%
eli5.show_weights(pipe['logreg'], top=30, feature_names=pipe['vectorizer'].get_feature_names())
# Out:
# /home/jovyan/.imgenv-gpu-a100-0/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +10.407
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         died
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.379
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         scan
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.784
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         despite
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.780
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         by
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.30%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.701
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         demonstrated
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.71%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.478
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         presentation
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.411
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         intubated
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.285
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         diagnosed
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.280
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         icu
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.251
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         progressive
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.107
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         started
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.017
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         significant
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.77%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.929
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         failure
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.633
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         distress
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.600
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         diagnosis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.53%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.547
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         daily
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.477
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         oral
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.385
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         tested
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.382
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         non
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.343
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         throat
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 92.96%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 103 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 92.40%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 117 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 92.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">

# %%
len(pipe['vectorizer'].vocabulary_)
# Out:
# 249

# %%
steps = [
    ('vectorizer', TfidfVectorizer(min_df=0.05, max_df=0.7)),
    ('logreg', LogisticRegression(C=8))
]

pipe = Pipeline(steps=steps)

# %%
pipe.fit(X_patient_train_honest, y_train)

preds = pipe.predict(X_patient_test_honest)

print(classification_report(y_true=y_test, y_pred=preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90        60
#            1       0.67      0.40      0.50        15
#
#     accuracy                           0.84        75
#    macro avg       0.77      0.68      0.70        75
# weighted avg       0.82      0.84      0.82        75

# %%
eli5.show_weights(pipe['logreg'], top=30, feature_names=pipe['vectorizer'].get_feature_names())
# Out:
# /home/jovyan/.imgenv-gpu-a100-0/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.128
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         rrt
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.115
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         despite
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.069
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         local
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.02%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.034
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         patient
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.917
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         scan
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.811
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         demonstrated
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.810
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         via
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.804
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ratio
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.801
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         75
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.71%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.781
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         by
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.777
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         intubated
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.692
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vomiting
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.659
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         daily
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.63%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.646
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         grade
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.71%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.635
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         hospital
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.628
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         icu
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.613
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         presentation
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.11%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.579
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ecg
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.511
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         diagnosed
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.63%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.505
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         required
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.492
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         troponin
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 84.72%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 237 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 84.98%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;

# %%
report = classification_report(y_test, preds, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report = df_classification_report.round(decimals=2)

df_classification_report = df_classification_report.astype(str)
df_classification_report.at['accuracy', 'precision'] = ''
df_classification_report.at['accuracy', 'recall'] = ''
df_classification_report.at['accuracy', 'support'] = df_classification_report.at['macro avg', 'support']
df_classification_report['support'] = df_classification_report['support'].str.replace('[.]0', '')
print(df_classification_report.to_latex())

# %%
steps = [
    ('vectorizer', TfidfVectorizer(min_df=0.005, max_df=0.95)),
    ('logreg', LogisticRegression(C=25))
]

pipe = Pipeline(steps=steps)

# %%
pipe.fit(X_rest_train, y_train)

preds = pipe.predict(X_rest_test)

print(classification_report(y_true=y_test, y_pred=preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91        60
#            1       0.70      0.47      0.56        15
#
#     accuracy                           0.85        75
#    macro avg       0.79      0.71      0.74        75
# weighted avg       0.84      0.85      0.84        75

# %%
report = classification_report(y_test, preds, output_dict=True)
df_classification_report = pd.DataFrame(report).transpose()
df_classification_report = df_classification_report.round(decimals=2)

df_classification_report = df_classification_report.astype(str)
df_classification_report.at['accuracy', 'precision'] = ''
df_classification_report.at['accuracy', 'recall'] = ''
df_classification_report.at['accuracy', 'support'] = df_classification_report.at['macro avg', 'support']
df_classification_report['support'] = df_classification_report['support'].str.replace('[.]0', '')
print(df_classification_report.to_latex())
# Out:
# \begin{tabular}{lllll}
# \toprule
# {} & precision & recall & f1-score & support \\
# \midrule
# 0            &      0.88 &   0.95 &     0.91 &      60 \\
# 1            &       0.7 &   0.47 &     0.56 &      15 \\
# accuracy     &           &        &     0.85 &      75 \\
# macro avg    &      0.79 &   0.71 &     0.74 &      75 \\
# weighted avg &      0.84 &   0.85 &     0.84 &      75 \\
# \bottomrule
# \end{tabular}

# %%
len(pipe['vectorizer'].vocabulary_)
# Out:
# 2563

# %%
steps = [
    ('vectorizer', TfidfVectorizer(min_df=0.01)),
    ('logreg', LogisticRegression(C=25))
]

pipe = Pipeline(steps=steps)

# %%
pipe.fit(X_all_train, y_train)

preds = pipe.predict(X_all_test)

print(classification_report(y_true=y_test, y_pred=preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92        60
#            1       0.78      0.47      0.58        15
#
#     accuracy                           0.87        75
#    macro avg       0.83      0.72      0.75        75
# weighted avg       0.86      0.87      0.85        75
