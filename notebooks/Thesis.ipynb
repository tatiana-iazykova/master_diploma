# %% [markdown]
# # Get data from Kaggle

# %%
# %%capture
# !pip install kaggle

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/HSE/Thesis"

# %%
# !kaggle datasets download -d allen-institute-for-ai/CORD-19-research-challenge

# %% [markdown]
# # Parse tables html

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# Utilizing tocilizumab for the treatment of cytokine release syndrome in COVID-19

# %%
url_PMC7229471 = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7229471/'
r_PMC7229471 = requests.get(url_PMC7229471)

# %%
df_PMC7229471 = pd.read_html(r_PMC7229471.text, header=0)

# %%
df_PMC7229471[0]
# Out:
#    Patient  Age  ...            Disposition Total hospital LOS
# 0        1   37  ...    Home with self-care               13.0
# 1        2   55  ...  Home with family care               21.0
# 2        3   67  ...                  Rehab               22.0
# 3        4   54  ...    Home with self-care                8.0
# 4        5   65  ...     Still hospitalized                NaN
# 5        6   88  ...                Expired               12.0
# 6        7   69  ...                Expired                6.0
# 7        8   42  ...     Still hospitalized                NaN
# 8        9   63  ...    Home with self-care               13.0
#
# [9 rows x 15 columns]

# %% [markdown]
# Tocilizumab treatment in COVID‐19: A single center experience

# %%
url_PMC7262125 = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7262125/table/jmv25801-tbl-0001/?report=objectonly'
r_PMC7262125 = requests.get(url_PMC7262125)

# %%
df_PMC7262125 = pd.read_html(r_PMC7262125.text, header=0)

# %%
df_PMC7262125[0]
# Out:
#     Case No.  Age  Sex  ...     Therapy.5 Therapy.6 Therapy.7
# 0   Case No.  Age  Sex  ...         Day 5     Day 6     Day 7
# 1          1   73    M  ...             …         …         …
# 2          2   62    M  ...             …         …         …
# 3          3   62    M  ...  MP 80 mg bid         …         …
# 4          4   74    M  ...             …         …         …
# 5          5   72    M  ...             …         …         …
# 6          6   73    M  ...             …         …         …
# 7          7   65    M  ...  MP 80 mg bid         …         …
# 8          8   66    F  ...             …         …         …
# 9          9   73    M  ...             …         …         …
# 10        10   77    M  ...             …         …         …
# 11        11   65    F  ...      MP 40 mg  MP 40 mg         …
# 12        12   77    M  ...             …         …         …
# 13        13   75    M  ...             …         …         …
# ...

# %% [markdown]
# Characteristics of ischaemic stroke associated with COVID-19

# %%
url_PMC7231545 = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7231545/'
r_PMC7231545 = requests.get(url_PMC7231545)

# %%
df_PMC7231545 = pd.read_html(r_PMC7231545.text, header=0)

# %%
df_PMC7231545[0]
# Out:
#                                            Unnamed: 0  ...                                          Patient 6
# 0                         Demographic characteristics  ...                                                NaN
# 1                                          Age, years  ...                                                 73
# 2                                                 Sex  ...                                               Male
# 3                                     Medical history  ...  Gastric carcinoma (resected), benign essential...
# 4                  Symptoms at COVID-19 disease onset  ...                    Shortness of breath, tachypnoea
# 5                                   Initial treatment  ...                        Antibiotics, oxygen therapy
# 6   Days from COVID-19 symptom onset to ischaemic ...  ...                                                  8
# ...

# %% [markdown]
# Acute cerebrovascular disease following COVID-19: a single center, retrospective, observational study

# %%
url_PMC7371480 = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7371480/'
r_PMC7371480 = requests.get(url_PMC7371480)

# %%
df_PMC7371480 = pd.read_html(r_PMC7371480.text, header=0)

# %%
df_PMC7371480[0]
# Out:
#     Unnamed: 0 Type of CVD  ... Treatment of CVD Outcome event
# 0            1         AIS  ...     Antiplatelet      Survival
# 1            2         AIS  ...     Antiplatelet      Survival
# 2            3         AIS  ...     Antiplatelet      Survival
# 3            4         AIS  ...     Antiplatelet         Death
# 4            5         AIS  ...     Antiplatelet         Death
# 5            6         AIS  ...     Antiplatelet         Death
# 6            7         AIS  ...    Anticoagulant         Death
# 7            8         AIS  ...    Anticoagulant      Survival
# 8            9         AIS  ...    Anticoagulant      Survival
# 9           10         AIS  ...    Anticoagulant         Death
# 10          11         ICH  ...              NaN         Death
#
# [11 rows x 14 columns]

# %% [markdown]
# Stroke in patients with SARS-CoV-2 infection: case series

# %%
url_PMC7238403 = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7238403/'
r_PMC7238403 = requests.get(url_PMC7238403)

# %%
df_PMC7238403 = pd.read_html(r_PMC7238403.text, header=0)

# %%
df_PMC7238403[0]
# Out:
#   Case no. (age, sex)  ...  Outcome
# 0           1 (64, M)  ...    Death
# 1           2 (75, M)  ...    Death
# 2           3 (82, M)  ...    Death
# 3           4 (76, F)  ...  mRS = 4
# 4           5 (57, M)  ...    Death
# 5           6 (57, M)  ...    Death
#
# [6 rows x 9 columns]

# %% [markdown]
# #Parse tables pdf

# %%
# %%capture 
# !pip install tabula-py

# %%
import tabula
from bs4 import BeautifulSoup
import requests


latest_report = f'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7228449/pdf/rct-publish-ahead-of-print-10.1097.rct.0000000000001023.pdf'
file = latest_report

from urllib.request import Request, urlopen
f = open('temp.pdf', 'wb')
url_request = Request(file, 
                      headers={"User-Agent": "Mozilla/5.0"})
webpage = urlopen(url_request).read()
f.write(webpage)
f.close()

tables = tabula.read_pdf('temp.pdf', stream=False, pages = "all", multiple_tables = True)
# Out:
# Got stderr: Jul 11, 2021 12:21:36 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Jul 11, 2021 12:21:36 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Jul 11, 2021 12:21:36 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts

# %%
len(tables)
# Out:
# 2

# %%
import tabula
 
f = "https://raw.githubusercontent.com/tatiana-iazykova/Files-for-reference/main/jmv.26111.pdf"
 
tables = tabula.read_pdf(f, pages = "all", multiple_tables = True)
# Out:
# Got stderr: Apr 23, 2021 8:37:44 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for g415 (2) in font DIJPJH+Calibri-Bold

# %%
tables[1]
# Out:
#    Case number Sex  ...    M Hospitalization day of tocilizumab application
# 0       Case 1   M  ...    ✓                                            8‐9
# 1       Case 2   F  ...    ✓                                            6‐7
# 2       Case 3   F  ...    ✓                                            5‐6
# 3       Case 4   M  ...    ✓                                            2‐3
# 4       Case 5   F  ...    ✓                                            3‐4
# 5       Case 6   M  ...    ✓                                            4‐5
# 6       Case 7   M  ...    ✓                                            6‐7
# 7       Case 8   M  ...  NaN                                            6‐7
# 8       Case 9   M  ...  NaN                                           9‐10
# 9      Case 10   F  ...  NaN                                           9‐10
# 10     Case 11   F  ...  NaN                                            5‐6
# ...

# %% [markdown]
# # Let the work begin

# %%
import pandas as pd
import numpy as np
import json
from tqdm.auto import tqdm
import os

# %%
# %%capture
pip install stanza

# %%
import stanza

# %%
stanza.download('en', package='mimic', processors={'ner': 'i2b2'})
nlp = stanza.Pipeline('en', package='mimic', processors={'ner': 'i2b2'})
# annotate clinical text
doc = nlp('The patient had a sore throat and was treated with Cepacol lozenges.')
# print out all entities
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# ...
# 2021-07-03 17:46:13 INFO: Downloading these customized packages for language: en (English)...
# ...
# | Processor       | Package |
# -----------------------------
# | tokenize        | mimic   |
# | pos             | mimic   |
# | lemma           | mimic   |
# | depparse        | mimic   |
# | ner             | i2b2    |
# | backward_charlm | mimic   |
# | pretrain        | mimic   |
# | forward_charlm  | mimic   |
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e0fa02fbff9a> in <module>()
# ----> 1 stanza.download('en', package='mimic', processors={'ner': 'i2b2'})
#       2 nlp = stanza.Pipeline('en', package='mimic', processors={'ner': 'i2b2'})
#       3 # annotate clinical text
#       4 doc = nlp('The patient had a sore throat and was treated with Cepacol lozenges.')
#       5 # print out all entities
#
# ...

# %%
# !unzip -j "/content/drive/MyDrive/HSE/Thesis/files/document_parses.zip" "pmc_json/PMC7262125.xml.json" -d "/content"
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/HSE/Thesis/files/document_parses.zip, /content/drive/MyDrive/HSE/Thesis/files/document_parses.zip.zip or /content/drive/MyDrive/HSE/Thesis/files/document_parses.zip.ZIP.

# %%
# with open('PMC7229471.xml.json') as f:
#   data = json.load(f)

# %%
# data['metadata']['title']
# Out:
# 'Utilizing tocilizumab for the treatment of cytokine release syndrome in COVID-19'

# %%
# !unrar x "/content/drive/MyDrive/HSE/Thesis/files/pmc_json_df.rar" "/content"
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/HSE/Thesis/files/pmc_json_df.rar
#
#   OK
# All OK

# %%
df = pd.read_csv('pmc_json_df.csv')

# %%
df.cord_id = df.cord_id.astype("category")
df.article_id = df.article_id.astype("category")
df.title = df.title.fillna('None')

# %%
#PMC7229471, PMC7262125, PMC7300754

# %%
df[df.article_id == 'PMC7262125']
# Out:
#                                                      text  ...   cord_id
# 105784  In December 2019, A novel coronavirus disease ...  ...  zwpqwpry
#
# [1 rows x 4 columns]

# %%
df[df.text.str.contains('Tocilizumab challenge', case=False)]
# Out:
# Empty DataFrame
# Columns: [text, article_id, title, cord_id]
# Index: []

# %%
df.iloc[105784].text

# %%
df.iloc[7588].text #pdf

# %% [markdown]
# # Regex

# %%
covid_study = df[df.text.str.contains('(year-old)[^\w](?! (children)|(people)|((wo)?men))|(year old)[^\w](?! (children)|(people)|((wo)?men))|(‐year‐old)[^\w](?! (children)|(people)|((wo)?men))', 
                                      case=False)]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
covid_study = covid_study[covid_study.text.str.contains('corona( |-)?virus|covid-19|SARS-CoV|2019-nCoV|MERS-CoV', case=False)]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
covid_study
# Out:
#                                                      text  ... year_count
# 2       A plethora of cutaneous manifestations have be...  ...          1
# 6       Coronaviruses (CoVs) form a large group of env...  ...          2
# 22      A 15 year-old, previously healthy African-Amer...  ...          1
# 24      Both reported outbreaks from California (CA) a...  ...          1
# 37      The Middle East respiratory syndrome coronavir...  ...          1
# ...                                                   ...  ...        ...
# 126438  \n•Ethical approval for this study was obtaine...  ...          2
# 126462  It has been close to six months since the Worl...  ...          3
# 126467  A novel coronavirus named severe acute respira...  ...          2
# 126470  The patient is a 34‐year‐old man from Australi...  ...          1
# 126476  Surgical resection of one or both thyroid lobe...  ...          1
#
# [9132 rows x 5 columns]

# %%
import re
def age_count(x):
  expr = ['year-old[^\w](?! (children)|(people)|((wo)?men))', 'year old[^\w](?! (children)|(people)|((wo)?men))', '‐year‐old[^\w](?! (children)|(people)|((wo)?men))']
  res = []
  for e in expr:
    res.append(re.findall(e, x, flags=re.IGNORECASE))
  return len([item for sublist in res for item in sublist if item])

# %%
covid_study['year_count'] = covid_study.text.apply(age_count)

# %%
covid_study = covid_study[(covid_study.year_count < 50) & (covid_study.title != 'Posters')]

# %%
covid_study.head()

# %%
print(f'Number of potenital patients: {covid_study.year_count.sum()}')
print(f'Number of maximum potential patients in one article: {covid_study.year_count.max()}')
# Out:
# Number of potenital patients: 16781
# Number of maximum potential patients in one article: 43

# %%
np.argmax(covid_study.year_count)
# Out:
# 7859

# %%
with pd.option_context('display.max_colwidth', None):
  display(covid_study[covid_study.article_id == 'PMC7354961'])

# %%
df[df.article_id == 'PMC7354961']
# Out:
#                                                     text  ...   cord_id
# 27420  Dear Editor, A 53-year-old woman visited our e...  ...  xlxq96ws
#
# [1 rows x 4 columns]

# %% [markdown]
# # **Articles for Golden Set**
#
# * PMC7273035
# * PMC7955911 (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7955911/) + lab data
#
# Cerebrovascular disease in patients with COVID-19: neuroimaging, histological and clinical description **TBD**
# 1. * PMC7454411 (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7454411/pdf/awaa239.pdf) - take a look at the structure (Patient sections) alternative link (https://academic.oup.com/brain/article/143/10/3089/5869424)
#
# * PMC7325208
#
# Neurovascular Complications in COVID-19 Infection: Case Series  **TBD**
# 2. * PMC7583125 http://www.ajnr.org/content/41/9/1632.long
#
# * PMC7309300
# * PMC7238403
# * PMC7179995
#
# * PMC7250248 (+ lab data)
#
# * PMC7152619
# * PMC7237227 (+ lab data)
#
# 3. https://www.tandfonline.com/doi/full/10.1080/02688697.2020.1787343
#
# * PMC7313569 (+ lab data)
# * PMC7307498
# * PMC7354961
# * PMC7276127 (+ lab data)

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ### PMC7955911 (parsing + lab data)

# %%
url = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7955911/'
r = requests.get(url)

# %%
bs=BeautifulSoup(r.text, "html5lib") 
text=" ".join([p.text for p in bs.find_all("p")[6:-1]])

# %%
df_PMC7955911 = pd.read_html(r.text, header=0)[0]

# %%
df_PMC7955911.head() #laboratory data
# Out:
#             Parameters Result     Normal range
# 0               Sodium    135   137–145 mmol/L
# 1            Potassium    4.5   3.5–5.1 mmol/L
# 2              Glucose     93     70–100 mg/dL
# 3  Blood urea nitrogen     32       9–20 mg/dL
# 4           Creatinine   1.05  0.66–1.25 mg/dL

# %% [markdown]
# ### PMC7163302 (parsing)

# %%
url_PMC7163302 = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7163302/'
r_PMC7163302 = requests.get(url_PMC7163302)

# %%
bs_PMC7163302 = BeautifulSoup(r_PMC7163302.text, "html5lib") 
text_PMC7163302=" ".join([p.text for p in bs_PMC7163302.find_all("p")[1:-1]])

# %% [markdown]
# ### PMC7250248 (LAB DATA)

# %%
url_PMC7250248 = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7250248/'
r_PMC7250248 = requests.get(url_PMC7250248)

# %%
df_PMC7250248 = pd.read_html(r_PMC7250248.text, header=0)[0]

# %%
df_PMC7250248.head() #laboratory data
# Out:
#                                           Unnamed: 0  ...       Patient #2 mean (range)
# 0                                        Vital signs  ...                   Vital signs
# 1  Systolic blood pressure (BP) while on heparin ...  ...                  117 (47–204)
# 2               Diastolic BP while on heparin (mmHg)  ...                   58 (29–112)
# 3                                  Oxygen saturation  ...                 94% (71–100%)
# 4                       Coagulation/hematologic labs  ...  Coagulation/hematologic labs
#
# [5 rows x 3 columns]

# %% [markdown]
# ### PMC7237227 (LAB DATA)

# %%
url_PMC7237227 = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7237227/'
r_PMC7237227 = requests.get(url_PMC7237227)

# %%
df_PMC7237227 = pd.read_html(r_PMC7237227.text, header=0)

# %%
df_PMC7237227[0].head() #laboratory data
# Out:
#          Prothrombin time  11–14 s   12.8
# 0  Prothrombin time ratio      NaN   0.95
# 1                     INR  0.8–1.1   0.93
# 2              PT Control      NaN  13.50
# 3                    APTT  28–41 s  30.90

# %%
df_PMC7237227[1].head()
# Out:
#       Bilirubin (total)   0–1.0 mg/dL       0.3
# 0  Alkaline phosphatase    40–129 U/L       108
# 1             SGPT(ALT)      0–41 U/L  196 high
# 2         Total protein  6.6–8.7 g/dL       7.4
# 3               Albumin  3.4–4.8 g/dL       3.6
# 4              Globulin  2.8–3.4 g/dL  3.8 high

# %%
df_PMC7237227[2].head()
# Out:
#         G-6PD screen               Normal  Normal.1
# 0  G6PD quantitative  146–376 u/10^12 RBC       173

# %% [markdown]
# ### PMC7313569 (LAB DATA)

# %%
url_PMC7313569 = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7313569/'
r_PMC7313569 = requests.get(url_PMC7313569)

# %%
df_PMC7313569 = pd.read_html(r_PMC7313569.text, header=0)[0]

# %%
df_PMC7313569.head() #laboratory data
# Out:
#                    Parameters              Patient 1          Patient 2
# 0             Age/Sex (years)                   56/M               72/M
# 1                Risk factors  Hypertension, smoking  Diabetes mellitus
# 2       Hemogram (Hb/TLC/DLC)     15.1/23, 320/N85L6  15/11, 260/N82L14
# 3  Platelet count (per cu mm)               2.2 lakh          1.65 lakh
# 4                         INR                   1.07               1.00

# %% [markdown]
# ### PMC7276127 (LAB DATA)

# %%
url_PMC7276127 = 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7276127/'
r_PMC7276127 = requests.get(url_PMC7276127)

# %%
df_PMC7276127 = pd.read_html(r_PMC7276127.text, header=0)[0]

# %%
df_PMC7276127.head()
# Out:
#                                       Unnamed: 0  ...                                      Patient 5
# 0                           Patient demographics  ...                           Patient demographics
# 1                                    Age (years)  ...                                             52
# 2                                            Sex  ...                                           Male
# 3                          Vascular risk factors  ...                         HTNHigh cholesterolIHD
# 4  Laboratory findings at the time ICH diagnosed  ...  Laboratory findings at the time ICH diagnosed
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Golden Set

# %%
golden_df = pd.DataFrame({'text': text, 'article_id': 'PMC7955911', 'title': 'Massive biventricular thrombi complicating new-onset heart failure in a patient with suspected COVID-19'}, index=[0])
golden_df = golden_df.append(pd.DataFrame({'text': text_PMC7163302, 'article_id': 'PMC7163302', 'title': 'COVID-19 and intracerebral haemorrhage: causative or coincidental?'}, index=[1]))

# %%
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7273035'].drop(['cord_id','year_count'], axis=1))
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7325208'].drop(['cord_id','year_count'], axis=1))
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7309300'].drop(['cord_id','year_count'], axis=1))
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7238403'].drop(['cord_id','year_count'], axis=1))
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7179995'].drop(['cord_id','year_count'], axis=1))
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7280656'].drop(['cord_id','year_count'], axis=1))
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7250248'].drop(['cord_id','year_count'], axis=1))
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7152619'].drop(['cord_id','year_count'], axis=1))
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7237227'].drop(['cord_id','year_count'], axis=1))
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7313569'].drop(['cord_id','year_count'], axis=1))
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7354961'].drop(['cord_id','year_count'], axis=1))
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7307498'].drop(['cord_id','year_count'], axis=1))
golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7276127'].drop(['cord_id','year_count'], axis=1))

# %%
golden_df['num_patients'] = [1, 1, 1, 5, 3, 6, 1, 1, 2, 3, 1, 2, 1, 3, 5]

# %%
# golden_df = golden_df.append(covid_study[covid_study.article_id == 'PMC7276127'].drop('cord_id', axis=1))

# %%
golden_df.reset_index(drop=True)
# Out:
#                                                  text  ... year_count
# 0   cDepartment of Cardiology, Capital Health Regi...  ...          1
# 1   Try out PMC Labs and tell us what you think. L...  ...          1
# 2   COVID‐19 is a coronavirus disease, caused by t...  ...          1
# 3   The ongoing pandemic caused by coronavirus dis...  ...          5
# 4   The novel coronavirus 2019 (COVID-19) is a β-c...  ...          4
# 5   Italy was the first country in Europe to witne...  ...          6
# 6   To rapidly communicate information on the glob...  ...          1
# 7   On 17 March 2020, a 69‐year‐old lady presented...  ...          1
# 8   A 62-year-old man with a remote history of col...  ...          2
# 9   Coronavirus disease 2019 (COVID-19) is caused ...  ...          5
# 10  Coronavirus disease 2019 (COVID-19) started in...  ...          2
# 11  Early December 2019 was associated with health...  ...          2
# ...

# %%
golden_df = golden_df.reset_index(drop=True)

# %%
golden_df['year_count'] = golden_df.text.apply(age_count)

# %%
print(', '.join(golden_df.article_id.to_list()))
# Out:
# PMC7955911, PMC7163302, PMC7273035, PMC7325208, PMC7309300, PMC7238403, PMC7179995, PMC7280656, PMC7250248, PMC7152619, PMC7237227, PMC7313569, PMC7354961, PMC7307498, PMC7276127

# %%
golden_df.num_patients.sum()
# Out:
# 36

# %%
golden_df
# Out:
#                                                  text  ... year_count
# 0   cDepartment of Cardiology, Capital Health Regi...  ...          1
# 1   Try out PMC Labs and tell us what you think. L...  ...          1
# 2   COVID‐19 is a coronavirus disease, caused by t...  ...          1
# 3   The ongoing pandemic caused by coronavirus dis...  ...          5
# 4   The novel coronavirus 2019 (COVID-19) is a β-c...  ...          4
# 5   Italy was the first country in Europe to witne...  ...          6
# 6   To rapidly communicate information on the glob...  ...          1
# 7   On 17 March 2020, a 69‐year‐old lady presented...  ...          1
# 8   A 62-year-old man with a remote history of col...  ...          2
# 9   Coronavirus disease 2019 (COVID-19) is caused ...  ...          5
# 10  Coronavirus disease 2019 (COVID-19) started in...  ...          2
# 11  Early December 2019 was associated with health...  ...          2
# ...

# %% [markdown]
# # Scraper

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
many = covid_study[covid_study.year_count > 1]

# %%
many.year_count.sum()
# Out:
# 12905

# %%
a = covid_study.article_id.to_list()

links = [f'https://www.ncbi.nlm.nih.gov/pmc/articles/{x}/' for x in a]

# %%
import re
year = re.compile('(year-old)[^\w](?! (children)|(people)|((wo)?men))|(year old)[^\w](?! (children)|(people)|((wo)?men))|(‐year‐old)[^\w](?! (children)|(people)|((wo)?men))', 
                                      flags=re.IGNORECASE)

# %%
covid = re.compile('(corona( |-)?virus)|(covid-19)|(SARS-CoV)|(2019-nCoV)|(MERS-CoV)', flags=re.IGNORECASE)

# %%
all = []
strange_links = []
pmcs = []

for link in tqdm(links):
    pmc = re.search('PMC\d+', link).group(0)
    r = requests.get(link)
    bs=BeautifulSoup(r.text, "html5lib") 
    try:
      for i in bs.find_all(text=re.compile('(Case|Patient)( \d+)?$')):
          b_tag = i.parent
          p_tag = b_tag.parent
          next_p_tag = p_tag.findNext('p')
          if year.search(next_p_tag.contents[0]) and covid.search(next_p_tag.contents[0]):
            all.append(next_p_tag.contents[0])
            pmcs.append(pmc)
    except:
      print(link)
      strange_links.append(link)

strange_links1 = []

for link in tqdm(strange_links):
    pmc = re.search('PMC\d+', link).group(0)
    r = requests.get(link)
    bs=BeautifulSoup(r.text, "html5lib") 
    try:
      for i in bs.find_all(text=re.compile('(Case|Patient)( \d+)?$')):
        b_tag = i.parent
        p_tag = b_tag.parent
        next_p_tag = p_tag.findNext('p').findNext('p')
        if year.search(next_p_tag.contents[0]) and covid.search(next_p_tag.contents[0]):
          all.append(next_p_tag.contents[0])
          pmcs.append(pmc)
    except:
      print(link)
      strange_links1.append(link)

    # except:
    #   try:
    #     all1 = []
    #     for i in bs.find_all('strong'):
    #       if re.search('(Case|Patient)', str(i)):
    #         b1 = i.next_sibling
    #         all1.append(b1)
    #     all1 = [x.lstrip(', ').strip() for x in all1]
    #     all1 = [year.search(x) and covid.search(x) for x in all1]
    #     _ =  [pmcs.append(pmc) for i in range(len(all1))]
    #     all.extend(all1)
    #   except:
    #     try:
    #       all6 = []
    #       for i in bs.find_all('p'):
    #         if i.contents:
    #           if str(i.contents[0]).startswith('Case') and year.search(str(i.contents[0])) and covid.search(str(i.contents[0])):
    #             all6.append(str(i.contents[0]))
    #             pmcs.append(pmc)
    #           elif str(i.contents[0]).startswith('Patient') and year.search(str(i.contents[0])) and covid.search(str(i.contents[0])):
    #             all6.append(str(i.contents[0]))
    #             pmcs.append(pmc)
    #       all.extend(all6)
    #     except:
    #       strange_links.append(link)
# Out:
# ...
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7784786/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7271091/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7483499/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7832449/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7365839/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7700357/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7346678/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7094943/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7173179/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7537988/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4230886/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7436421/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1624813/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7252050/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7781099/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7417084/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7744651/
# ...

# %%
strange_links2 = []
for link in tqdm(strange_links1):
  try:
    all1 = []
    for i in bs.find_all('strong'):
      if re.search('(Case|Patient)', str(i)):
        b1 = i.next_sibling
        all1.append(b1)
    all1 = [x.lstrip(', ').strip() for x in all1]
    all1 = [year.search(x) and covid.search(x) for x in all1]
    _ =  [pmcs.append(pmc) for i in range(len(all1))]
    all.extend(all1)
  except:  
      strange_links2.append(link)

# %%
strange_links3 = []
for link in tqdm(strange_links1):
  try:
    all6 = []
    for i in bs.find_all('p'):
      if i.contents:
        if str(i.contents[0]).startswith('Case') and year.search(str(i.contents[0])) and covid.search(str(i.contents[0])):
          all6.append(str(i.contents[0]))
          pmcs.append(pmc)
        elif str(i.contents[0]).startswith('Patient') and year.search(str(i.contents[0])) and covid.search(str(i.contents[0])):
          all6.append(str(i.contents[0]))
          pmcs.append(pmc)
    all.extend(all6)
  except:
    strange_links3.append(link)

# %%
len(set(all))
# Out:
# 718

# %%
all = [str(a) for a in all]
df_patients = pd.DataFrame({'patient_description': all, 'pmcs': pmcs})

# %%
df_patients = df_patients[df_patients.patient_description.apply(len) > 100]
df_patients = df_patients.drop_duplicates()

# %%
len(df_patients)
# Out:
# 718

# %%
# %%capture
# !pip install unidecode word2number

# %%
from pprint import pprint
from bs4 import BeautifulSoup
from html import unescape
import unicodedata
import string
import unidecode
from word2number import w2n

# %%
def escape_html(text):
    soup = BeautifulSoup(unescape(text), 'html.parser')
    text = soup.text
    text = unicodedata.normalize('NFKC', text)
    return text

def replace_dashes(text):
    dashes = '-‐‑‒–—―'
    for dash in dashes:
        text = text.replace(dash, '-')
    return text

def my_replace(match):
    match = match.group()
    return unidecode.unidecode(match)

def preclean(text):
    text = escape_html(text)
    text = re.sub('([^А-яЁё«»©])', my_replace, text)
    text = replace_dashes(text)
    text = text.replace('  ', ' ').replace('  ', ' ').replace('  ', ' ')
    text = text.strip()
    return text

# %%
tqdm.pandas()
df_patients.patient_description = df_patients.patient_description.progress_apply(preclean)
# Out:
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# ...

# %%
df_patients.head()
# Out:
#                                  patient_description        pmcs
# 0  A 52-year-old man with longstanding well-contr...  PMC7644423
# 1  A 64-year-old man with history of atrial fibri...  PMC7644423
# 2  A 12-year-old female, with no known medical co...  PMC7853748
# 3  In the first case, a 39 year-old male, health ...  PMC7126798
# 4  In the third case, a 29 year-old housekeeper f...  PMC7126798

# %%
def get_age(text):
  age = re.search('\d\d?(?=(-| |(- ))?year(-| )?old)', text)
  if age:
    return age.group()
  else:
    age = re.search('\w+(?=(-| |(- ))?year(-| )?old)', text)
    if age:
      age = w2n.word_to_num(age.group())
      return age

# %%
df_patients['age'] = df_patients.patient_description.progress_apply(get_age)

# %%
df_patients.head()
# Out:
#                                  patient_description        pmcs age
# 0  A 52-year-old man with longstanding well-contr...  PMC7644423  52
# 1  A 64-year-old man with history of atrial fibri...  PMC7644423  64
# 2  A 12-year-old female, with no known medical co...  PMC7853748  12
# 3  In the first case, a 39 year-old male, health ...  PMC7126798  39
# 4  In the third case, a 29 year-old housekeeper f...  PMC7126798  29

# %%
df_patients.to_csv('/content/drive/MyDrive/HSE/Thesis/files/patients_description.csv', index=False)

# %%
df_patients.to_excel('/content/drive/MyDrive/HSE/Thesis/files/patients_description.xls', index=False)

# %% [markdown]
# ## Markup

# %%
texts = golden_df.text.to_list()

# %%
from spacy.lang.en import English
nlp = English()
tokenizer = nlp.tokenizer

# %%
def get_markup(texts, sep=False):
  words = []
  tags =[]

  for text in texts:
    doc = tokenizer(text)
    for token in doc:
      words.append(token.text)
      tags.append('O')
    if sep:
      words.append('EOS')
      tags.append('EOS')

  markup = pd.DataFrame({'words': words, 'tags': tags})
  return markup

# %%
text3 = [golden_df.iloc[3].text]

markup3 = get_markup(text3, sep= True)
markup3.to_excel('markup_five_patients.xlsx', index=False)

# %%
markup = get_markup(texts)
markup['tags'] = ''
markup.to_excel('markup.xlsx', index=False)

# %% [markdown]
# # Project R

# %%
covid = df[df.text.str.contains('corona( |-)?virus|covid-19|SARS-CoV|2019-nCoV|MERS-CoV', case=False)]

# %%
vaccines = covid[covid.text.str.contains('vaccin(e|ation)|Pfizer|AstraZeneca|Sputnik( V)?|BioNTech|Sinopharm|Sinovac|Moderna|Covaxin', case=False)]

# %%
len(vaccines)

# %%
tmp = vaccines[vaccines.text.str.contains('(and so on)|(shouldn\'t)|(aren\'t)|(isn\'t)|(can\'t)|(ha(ve|s)n\'t)|(won\'t)|([^A-z](g|w)onna[^A-z])|([^A-z]gimme[^A-z])|(kung flu)|((China|Asian) virus)|([^A-z]Rona[^A-z])|([^A-z]corona(reezy)?[^A-z-]^(virus))|([^A-z]Coro(ne)?s[^A-z])|(Boomer Remover)|(Senior Deleter)|(Geriatric Dispatcher)|(covid(dy|sky|z))', case=False)]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
len(tmp)
# Out:
# 2190

# %%
import re
def cute_regex(x):
  expr = ['and so on', 'aren\'t','can\'t','haven\'t', 'hasn\'t', 'won\'t', '[^A-z]gonna[^A-z]', '[^A-z]wonna[^A-z]',
          '[^A-z]gimme[^A-z]', 'kung flu', 'China virus', 'Asian virus', 'shouldn\'t', 'isn\'t',
          '[^A-z]Rona[^A-z]', 'Coronareezy', '[^A-z]corona[^A-z-]',  '[^A-z]Corones[^A-z]', '[^A-z]coros[^A-z]', 'Boomer Remover',
          'Senior Deleter', 'Geriatric Dispatcher', 'coviddy', 'covidsky', 'convidz']
  res = []
  for e in expr:
    res.append(re.findall(e, x, flags=re.IGNORECASE))
  return [item for sublist in res for item in sublist if item]

# %%
tmp['contracted'] = tmp.text.apply(cute_regex)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tmp
# Out:
#                                                      text  ...                                         contracted
# 11      The evolution of the disease caused by the new...  ...                                [haven't,  corona,]
# 114     Systems approaches are increasingly being used...  ...                                        [and so on]
# 154     Developed throughout the ages to code biologic...  ...                                        [and so on]
# 267     These numbers are even more striking when cons...  ...      [aren't, haven't, isn't, isn't, isn't, isn't]
# 394     COVID 19, an ongoing pandemic, is the viral di...  ...                                        [and so on]
# ...                                                   ...  ...                                                ...
# 167394  Australia has an increasing older population a...  ...                                        [Shouldn't]
# ...

# %%
def count_apply(x,y):
  f = y.split()
  return len(x)/len(f)

# %%
tmp['count_contr'] = tmp.apply(lambda x: count_apply(x['contracted'], x['text']), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tmp
# Out:
#                                                      text  ... count_contr
# 11      The evolution of the disease caused by the new...  ...    0.000530
# 114     Systems approaches are increasingly being used...  ...    0.000354
# 154     Developed throughout the ages to code biologic...  ...    0.000117
# 267     These numbers are even more striking when cons...  ...    0.002290
# 394     COVID 19, an ongoing pandemic, is the viral di...  ...    0.000226
# ...                                                   ...  ...         ...
# 167394  Australia has an increasing older population a...  ...    0.000961
# 167398  In December 2019, an epidemic of coronavirus d...  ...    0.003862
# 167406  The novel coronavirus-2 (nCoV-2) responsible f...  ...    0.000879
# 167519  The Peripheral Nerve Society was founded in 19...  ...    0.000007
# 167584  Throughout recorded history, human population ...  ...    0.000284
#
# [2190 rows x 3 columns]

# %%
# tmp = tmp.drop(['article_id', 'title', 'cord_id'], axis=1)
tmp = tmp.drop(['article_id', 'title'], axis=1)

# %%
tmp.count_contr.max()
# Out:
# 0.012029912214154113

# %%
tmp.to_csv('dataset_science_pt1.csv', index=False)

# %% [markdown]
# # Make DF

# %%
# !unzip /content/drive/MyDrive/HSE/Thesis/CORD-19-research-challenge.zip -d train
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/HSE/Thesis/CORD-19-research-challenge.zip, /content/drive/MyDrive/HSE/Thesis/CORD-19-research-challenge.zip.zip or /content/drive/MyDrive/HSE/Thesis/CORD-19-research-challenge.zip.ZIP.

# %%
# %cd /content/train/document_parses/pmc_json
# Out:
# /content/train/document_parses/pmc_json

# %%
def get_json(dir):
  df = pd.DataFrame(columns=['text', 'article_id', "title"])
  for i in tqdm(os.listdir(dir)):
    if i.endswith(".json"):
      with open(i) as f:
        data = json.load(f)
      text = ''
      for l in data['body_text']:
        text += l['text'] + ' '
      d = {'text': text, 'article_id': data["paper_id"], 'title': data["metadata"]['title']}
      df = df.append(d, ignore_index=True)
  return df

# %%
# !rm -r /content/pdf_json

# %%
df_1 = get_json('.')

# %%
df = pd.read_csv('/content/drive/MyDrive/HSE/Thesis/pdf_json_df.csv')

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.to_csv('/content/pdf_json_df1.csv', index=False)

# %%
df_1

# %%
df_1.to_csv('/content/pmc_json_df.csv', index=False)

# %%
# !cp -r /content/pmc_json_df.csv /content/drive/MyDrive/HSE/Thesis
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
